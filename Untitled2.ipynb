# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.pib.gov.in/PressReleseDetail.aspx?PRID=1701571"  # Replace with the actual URL of the page

# Fetch the webpage content
headers = {
    'Accept-Language': 'hi-IN,hi;q=0.9,en-US;q=0.8,en;q=0.7',
}

# Fetch the webpage content with specified headers
response = requests.get(url, headers=headers)
html_content = response.content

soup = BeautifulSoup(html_content, 'html.parser')

# Find all <a> tags within the specified div
a_tags = soup.select('#ContentPlaceHolder1_PNLrEL a.listLeftrel2')

# Iterate through each <a> tag and extract details
for a_tag in a_tags:
    title = a_tag['title']
    link = a_tag['href']
    
    # Check if the next sibling is a <span> with the class 'publishdatesmall'
    date_span = a_tag.find_next('span', class_='publishdatesmall')
    date = date_span.text if date_span else 'Date not available'

    print(f"Title: {title}\nLink: {link}\nDate: {date}\n")
# Out:
# Title: Centre meets State Food Secretaries to discuss procurement during Rabi Marketing Season (RMS) 2024-25 and Kharif Marketing Season (2023-24)
# Link: javascript:void(0)
# Date: Date not available

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#                                               0.0/10.0 MB ? eta -:--:--
#                                              0.0/10.0 MB 640.0 kB/s eta 0:00:16
#                                               0.2/10.0 MB 2.2 MB/s eta 0:00:05
#      -                                        0.5/10.0 MB 3.6 MB/s eta 0:00:03
#      -                                        0.5/10.0 MB 2.8 MB/s eta 0:00:04
#      --                                       0.5/10.0 MB 2.4 MB/s eta 0:00:04
#      --                                       0.5/10.0 MB 1.9 MB/s eta 0:00:06
#      --                                       0.7/10.0 MB 2.1 MB/s eta 0:00:05
#      ----                                     1.0/10.0 MB 2.8 MB/s eta 0:00:04
#      -----                                    1.4/10.0 MB 3.4 MB/s eta 0:00:03
#      ------                                   1.7/10.0 MB 3.6 MB/s eta 0:00:03
#      -------                                  1.8/10.0 MB 3.4 MB/s eta 0:00:03
#      -------                                  1.8/10.0 MB 3.4 MB/s eta 0:00:03
#      -------                                  1.8/10.0 MB 2.9 MB/s eta 0:00:03
#      --------                                 2.1/10.0 MB 3.2 MB/s eta 0:00:03
#      ---------                                2.5/10.0 MB 3.5 MB/s eta 0:00:03
#      -----------                              3.0/10.0 MB 3.9 MB/s eta 0:00:02
#      ------------                             3.1/10.0 MB 3.9 MB/s eta 0:00:02
#      ------------                             3.1/10.0 MB 3.8 MB/s eta 0:00:02
#      ------------                             3.1/10.0 MB 3.8 MB/s eta 0:00:02
#      ------------                             3.2/10.0 MB 3.4 MB/s eta 0:00:02
#      ---------------                          3.8/10.0 MB 3.8 MB/s eta 0:00:02
#      -----------------                        4.4/10.0 MB 4.2 MB/s eta 0:00:02
#      --------------------                     5.1/10.0 MB 4.7 MB/s eta 0:00:02
#      --------------------                     5.2/10.0 MB 4.6 MB/s eta 0:00:02
#      ---------------------                    5.3/10.0 MB 4.6 MB/s eta 0:00:02
#      ---------------------                    5.3/10.0 MB 4.6 MB/s eta 0:00:02
#      ---------------------                    5.3/10.0 MB 4.3 MB/s eta 0:00:02
#      -----------------------                  5.9/10.0 MB 4.5 MB/s eta 0:00:01
#      --------------------------               6.7/10.0 MB 4.8 MB/s eta 0:00:01
#      -----------------------------            7.3/10.0 MB 5.2 MB/s eta 0:00:01
#      -----------------------------            7.5/10.0 MB 5.2 MB/s eta 0:00:01
#      -----------------------------            7.5/10.0 MB 5.0 MB/s eta 0:00:01
#      ------------------------------           7.5/10.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------------          7.9/10.0 MB 4.9 MB/s eta 0:00:01
#      -----------------------------------      8.8/10.0 MB 5.3 MB/s eta 0:00:01
#      ---------------------------------------  10.0/10.0 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  10.0/10.0 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  10.0/10.0 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  10.0/10.0 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------- 10.0/10.0 MB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from selenium) (1.26.14)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#                                               0.0/460.2 kB ? eta -:--:--
#      ------------------------------------  450.6/460.2 kB 27.5 MB/s eta 0:00:01
#      ------------------------------------  450.6/460.2 kB 27.5 MB/s eta 0:00:01
#      -------------------------------------- 460.2/460.2 kB 4.8 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2022.12.7)
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (22.2.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pycparser in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\chaitanya\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.9.0)
# Installing collected packages: sortedcontainers, wsproto, typing_extensions, PySocks, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# Successfully installed PySocks-1.7.1 outcome-1.3.0.post0 selenium-4.18.1 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.10.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2009923'
driver.get(website_url)

# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
month_dropdown.select_by_value('4')  # Replace '4' with the desired month

# Re-locate the year dropdown after interacting with day and month dropdowns
year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

# Wait for the page to update with the selected date's news
time.sleep(2)  # Adjust the sleep duration based on your website's loading time

# Scraping news articles
news_articles = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li')
for article in news_articles:
    title = article.find_element(By.CSS_SELECTOR, 'a.listLeftrel2').text
    publish_date = article.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
    print(f"Title: {title}\nPublish Date: {publish_date}\n")

# Close the browser window
driver.quit()
# Out:
# Title: President’s Greetings on the Eve of Mahavir Jayanti
# Publish Date: Posted On: 24 Apr 2021
#
# Title: PRESS COMMUNIQUE
# Publish Date: Posted On: 24 Apr 2021
#
# Title: President’s Ram Navami Greetings
# Publish Date: Posted On: 20 Apr 2021
#
# Title: President’s Greetings on the eve of Birth Anniversary of dr. B.R. Ambedkar
# Publish Date: Posted On: 13 Apr 2021
#
# Title: President’s Greetings on the Eve of Puthandu Pirappu, Rongali Bihu, Naba Barsha and Vaisakhadi
# Publish Date: Posted On: 13 Apr 2021
#
# Title: President’s Greetings on the eve of Chaitra Sukladi, Ugadi, Gudi Padwa, Cheti Chand, Vaisakhi, Vishu, Navreh and Sajibu Cheiraoba
# Publish Date: Posted On: 12 Apr 2021
#
# Title: President of India’s Greetings on the eve of Easter
# Publish Date: Posted On: 03 Apr 2021
#
# Title: Vice President pays rich tributes to former Attorney General, Shri Soli Sorabjee
# Publish Date: Posted On: 30 Apr 2021
#
# Title: Unlock our gender dividend to drive growth, VP calls upon industry
# Publish Date: Posted On: 30 Apr 2021
#
# Title: Vice President calls for according highest priority to the health needs of women
# Publish Date: Posted On: 30 Apr 2021
#
# Title: Look beyond short-term profit and work for long-term sustainability- Vice President to business leaders
# Publish Date: Posted On: 27 Apr 2021
#
# Title: Vice President greets people on the eve of Mahavir Jayanti
# Publish Date: Posted On: 24 Apr 2021
#
# Title: Vice President greets people on the eve of Ram Navami
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Vice President condoles the demise of renowned Radiologist, Dr. Kakarla Subba Rao
# Publish Date: Posted On: 16 Apr 2021
#
# Title: Vice President urges the people to adopt COVID appropriate behavior
# Publish Date: Posted On: 14 Apr 2021
#
# Title: Vice President calls for ending every form of gender discrimination in the society
# Publish Date: Posted On: 12 Apr 2021
#
# Title: Vice President wishes nation ahead of the upcoming festivals 'Ugadi, Gudi Padava, Chaitra Sukladi, Cheti Chand, Vaisakhi, Vishu, Puthandu, Vaishkhadi and Bohag Bihu’
# Publish Date: Posted On: 12 Apr 2021
#
# Title: Committed to overall development of Jammu & Kashmir; Any external interference in India’s internal affairs unwarranted: Vice President
# Publish Date: Posted On: 09 Apr 2021
#
# Title: Vice President emphasises the need to maintain decency of language in public discourse
# Publish Date: Posted On: 06 Apr 2021
#
# Title: Vice President's message on the eve of Easter
# Publish Date: Posted On: 03 Apr 2021
#
# Title: Vice President calls upon the youth to imbibe the spirit of entrepreneurship and innovation
# Publish Date: Posted On: 03 Apr 2021
#
# Title: Promote reading habit among youngsters to strengthen foundational literacy: Vice President
# Publish Date: Posted On: 02 Apr 2021
#
# Title: Always remember your mother, mother tongue, motherland and native place – Vice President
# Publish Date: Posted On: 02 Apr 2021
#
# Title: People must elect their representatives on 4Cs—Character, Conduct, Calibre and Capacity: Vice President
# Publish Date: Posted On: 01 Apr 2021
#
# Title: PM reviews Covid related situation in a meeting with Empowered Groups
# Publish Date: Posted On: 30 Apr 2021
#
# Title: PM condoles death of Rohit Sardana
# Publish Date: Posted On: 30 Apr 2021
#
# Title: PM Condoles demise of Shri Soli Sorabjee
# Publish Date: Posted On: 30 Apr 2021
#
# Title: PM reviews Army’s preparedness & initiatives for Covid management
# Publish Date: Posted On: 29 Apr 2021
#
# Title: Prime Minister's telephonic Conversation with President Putin of Russian Federation
# Publish Date: Posted On: 28 Apr 2021
#
# Title: 1 Lakh Portable Oxygen Concentrators to be procured from PM CARES fund
# Publish Date: Posted On: 28 Apr 2021
#
# Title: PM reviews Covid related operations by Indian Air Force
# Publish Date: Posted On: 28 Apr 2021
#
# Title: PM Condoles demise of senior leader Shri Dattaji Chirandas ji
# Publish Date: Posted On: 28 Apr 2021
#
# Title: PM Speaks to Assam CM regarding earthquake, assures all possible help
# Publish Date: Posted On: 28 Apr 2021
#
# Title: PM Condoles death of Shri Manoj Das
# Publish Date: Posted On: 28 Apr 2021
#
# Title: PM’s telephonic conversation with Amir of Qatar
# Publish Date: Posted On: 27 Apr 2021
#
# Title: Prime Minister chairs a high-level meeting to review the Covid-19 related situation in the country
# Publish Date: Posted On: 27 Apr 2021
#
# Title: PM condoles demise of Gujarati poet Dadudan Gadhvi
# Publish Date: Posted On: 27 Apr 2021
#
# Title: PM greets people on the auspicious occasion of Hanuman Jayanti
# Publish Date: Posted On: 27 Apr 2021
#
# Title: Prime Minister's telephone conversation with President Biden of the United States of America.
# Publish Date: Posted On: 26 Apr 2021
#
# Title: Prime Minister reviews preparations by Armed Forces to assist in Covid management
# Publish Date: Posted On: 26 Apr 2021
#
# Title: PM talks to Mizoram CM and takes stock of forest fire situation
# Publish Date: Posted On: 26 Apr 2021
#
# Title: Phone call between Prime Minister Shri Narendra Modi and H.E. Mr. Suga Yoshihide, Prime Minister of Japan
# Publish Date: Posted On: 26 Apr 2021
#
# Title: PM condoles the demise of Pandit Rajan Mishra
# Publish Date: Posted On: 25 Apr 2021
#
# Title: 551 PSA Oxygen Generation Plants to be set up in public health facilities across the country through PM CARES
# Publish Date: Posted On: 25 Apr 2021
#
# Title: English rendering of PM’s address in the 76th Episode of ‘Mann Ki Baat’ on 25.04.2021
# Publish Date: Posted On: 25 Apr 2021
#
# Title: PM greets people on Mahavir Jayanti
# Publish Date: Posted On: 25 Apr 2021
#
# Title: English rendering of PM’s address at National Panchayat Awards 2021 on the occasion of National Panchayati Raj Day
# Publish Date: Posted On: 24 Apr 2021
#
# Title: PM launches distribution of e-property cards under SWAMITVA scheme
# Publish Date: Posted On: 24 Apr 2021
#
# Title: PM to launch distribution of e-property cards under SWAMITVA scheme on 24th April
# Publish Date: Posted On: 23 Apr 2021
#
# Title: PM Modi interacts with leading oxygen manufacturers across the country via VC
# Publish Date: Posted On: 23 Apr 2021
#
# Title: PM Modi chairs meeting on Covid-19 situation with Chief Ministers of high burden states
# Publish Date: Posted On: 23 Apr 2021
#
# Title: PM condoles deaths in Virar Hospital fire, approves ex-gratia
# Publish Date: Posted On: 23 Apr 2021
#
# Title: Address by Prime Minister at the Leaders’ Summit on Climate 2021
# Publish Date: Posted On: 22 Apr 2021
#
# Title: PM cancels West Bengal tour due to high-level meetings to review COVID-19 situation
# Publish Date: Posted On: 22 Apr 2021
#
# Title: PM holds a high level meeting on oxygen supply and availability
# Publish Date: Posted On: 22 Apr 2021
#
# Title: PM condoles demise of Sitaram Yechury’s son Ashish
# Publish Date: Posted On: 22 Apr 2021
#
# Title: PM condoles death of Maulana Wahiduddin Khan.
# Publish Date: Posted On: 22 Apr 2021
#
# Title: Leaders’ Summit on Climate (April 22-23, 2021)
# Publish Date: Posted On: 21 Apr 2021
#
# Title: PM condoles the demise of Shri Shankha Ghosh.
# Publish Date: Posted On: 21 Apr 2021
#
# Title: PM greets people on Ram Navmi
# Publish Date: Posted On: 21 Apr 2021
#
# Title: PM wishes Civil Servants on the occasion of Civil Services Day
# Publish Date: Posted On: 21 Apr 2021
#
# Title: English rendering of PM's address to the nation on the COVID-19 situation
# Publish Date: Posted On: 20 Apr 2021
#
# Title: PM addresses the nation on the COVID-19 situation
# Publish Date: Posted On: 20 Apr 2021
#
# Title: PM Modi interacts with vaccine manufacturers from across the country
# Publish Date: Posted On: 20 Apr 2021
#
# Title: PM interacts with leaders of pharma industry
# Publish Date: Posted On: 19 Apr 2021
#
# Title: Prime Minister reviews Public Health Response to COVID-19 with the Nation’s Leading Doctors
# Publish Date: Posted On: 19 Apr 2021
#
# Title: PM condoles demise of noted writer Professor G. Venkatasubbaiah
# Publish Date: Posted On: 19 Apr 2021
#
# Title: PM condoles former Union Minister Shri Bachi Singh Rawat
# Publish Date: Posted On: 18 Apr 2021
#
# Title: Prime Minister interacts with regional public representatives and officials on Covid-19 in Varanasi
# Publish Date: Posted On: 18 Apr 2021
#
# Title: PM condoles demise of noted litterateur Narendra Kohli
# Publish Date: Posted On: 17 Apr 2021
#
# Title: Prime Minister reviews Preparedness of Public Health Response to COVID-19
# Publish Date: Posted On: 17 Apr 2021
#
# Title: PM condoles the passing away of legal scholar Shri KJ Shethna
# Publish Date: Posted On: 17 Apr 2021
#
# Title: PM condoles demise of actor Vivek
# Publish Date: Posted On: 17 Apr 2021
#
# Title: PM calls Acharya Mahamandaleshwar Poojya Swamy Avdheshanand Giri Ji
# Publish Date: Posted On: 17 Apr 2021
#
# Title: PM reviews status of oxygen availability to ensure adequate supply
# Publish Date: Posted On: 16 Apr 2021
#
# Title: PM’s greetings on Poyla Boishakh
# Publish Date: Posted On: 15 Apr 2021
#
# Title: PM interacts with the Governors on Covid-19 situation and Vaccination Drive in the country
# Publish Date: Posted On: 14 Apr 2021
#
# Title: English rendering of PM’s Address at the 95th Meeting of AIU and National Seminar of Vice Chancellors
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM addresses the Association of Indian Universities’ 95th Annual Meet and National Seminar of Vice-Chancellors
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM greets people of Assam on Bohag Bihu
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM’s Greetings on Vishu
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM’s greetings on Puthandu
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM greets people of Odisha on Odia New Year and Maha Bishuba Pana Sankranti
# Publish Date: Posted On: 14 Apr 2021
#
# Title: PM pays tribute to Bharat Ratna Dr Babasaheb Ambedkar on his Jayanti
# Publish Date: Posted On: 14 Apr 2021
#
# Title: Prime Minister’s remarks on 100th anniversary of the Kingdom of Jordan
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM congratulates His Majesty King Abdullah II and people of Hashemite Kingdom of Jordan on the occasion of the 100th anniversary of the founding of the state of Jordan
# Publish Date: Posted On: 13 Apr 2021
#
# Title: Raisina Dialogue-2021
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on the start of holy month of Ramzan
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM interacts with Intel CEO
# Publish Date: Posted On: 13 Apr 2021
#
# Title: Address by Prime Minister at the inaugural session of Raisina Dialogue 2021
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM to address Association of Indian Universities’ 95th Annual Meet and National Seminar of Vice-Chancellors on 14th April
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on various festivals
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM pays tribute to martyrs of Jallianwala Bagh massacre
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM Greets People on Ugadi
# Publish Date: Posted On: 13 Apr 2021
#
# Title: Prime Minister greets people on Cheti Chand
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on Navratri
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on Gudi Padwa
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM Greets People of Manipur on Sajibu Cheiraoba
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on Baisakhi
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM greets people on Nav Samvatsar
# Publish Date: Posted On: 13 Apr 2021
#
# Title: PM’s greetings on Navreh
# Publish Date: Posted On: 13 Apr 2021
#
# Title: English rendering of PM Narendra Modi's message on 'Tika Utsav'
# Publish Date: Posted On: 11 Apr 2021
#
# Title: ‘Tika Utsav’ is beginning of second major war against Corona: PM
# Publish Date: Posted On: 11 Apr 2021
#
# Title: PM pays tribute to Mahatma Jyotiba Phule on his birth anniversary
# Publish Date: Posted On: 11 Apr 2021
#
# Title: India is the fastest country to administer 100 million doses of Covid-19 vaccine
# Publish Date: Posted On: 10 Apr 2021
#
# Title: PM condoles the deaths in the road accident at Etawah
# Publish Date: Posted On: 10 Apr 2021
#
# Title: PM condoles loss of lives in hospital fire in Nagpur
# Publish Date: Posted On: 09 Apr 2021
#
# Title: India-Netherlands Virtual Summit
# Publish Date: Posted On: 09 Apr 2021
#
# Title: PM bows to Sri Sri Harichand Thakur on his Jayanti
# Publish Date: Posted On: 09 Apr 2021
#
# Title: English rendering of PM speech at the India-Netherlands Virtual Summit
# Publish Date: Posted On: 09 Apr 2021
#
# Title: PM Condoles passing way of HRH The Prince Philip, Duke of Edinburgh
# Publish Date: Posted On: 09 Apr 2021
#
# Title: English rendering of PM’s address at the release of Hindi Version of Odisha Itihaas by Dr. Harekrushna Mahtab
# Publish Date: Posted On: 09 Apr 2021
#
# Title: PM releases Hindi Version of Odisha Itihaas by Dr. Harekrushna Mahtab
# Publish Date: Posted On: 09 Apr 2021
#
# Title: English rendering of PM’s remarks at meeting with CMs of all states and UTs to take stock of the COVID-19 situation
# Publish Date: Posted On: 08 Apr 2021
#
# Title: PM interacts with the Chief Ministers on Covid-19 situation
# Publish Date: Posted On: 08 Apr 2021
#
# Title: India-Netherlands Virtual Summit (April 09, 2021)
# Publish Date: Posted On: 08 Apr 2021
#
# Title: Remarks by Prime Minister at India-Seychelles High Level Virtual Event (April 08, 2021)
# Publish Date: Posted On: 08 Apr 2021
#
# Title: English rendering of the Prime Minister’s address at High Level Committee to commemorate 400th Birth Anniversary (Prakash Purab) of Sri Guru Tegh Bahadur Ji
# Publish Date: Posted On: 08 Apr 2021
#
# Title: PM chairs meeting of High Level Committee to commemorate 400th Birth Anniversary (Prakash Purab) of Sri Guru Tegh Bahadur Ji
# Publish Date: Posted On: 08 Apr 2021
#
# Title: PM gets second dose of COVID-19 vaccine
# Publish Date: Posted On: 08 Apr 2021
#
# Title: English rendering of PM’s interaction with students, teachers and parents at "Pariksha Pe Charcha 2021”
# Publish Date: Posted On: 07 Apr 2021
#
# Title: PM interacts with students, teachers and parents in virtual edition of “Pariksha Pe Charcha 2021”
# Publish Date: Posted On: 07 Apr 2021
#
# Title: H.E. Mr. John Kerry, US Special Presidential Envoy for Climate meets Prime Minister Shri Narendra Modi
# Publish Date: Posted On: 07 Apr 2021
#
# Title: India-Seychelles High Level Virtual Event (April 8, 2021)
# Publish Date: Posted On: 07 Apr 2021
#
# Title: PM to release Hindi Version of Odisha Itihaas by Dr. Harekrushna Mahtab on 9th April 2021
# Publish Date: Posted On: 07 Apr 2021
#
# Title: PM to chair meeting of High Level Committee to commemorate the 400th Birth Anniversary (Prakash Purab) of Sri Guru Tegh Bahadur Ji on 8th April 2021
# Publish Date: Posted On: 07 Apr 2021
#
# Title: PM's message on World Health Day
# Publish Date: Posted On: 07 Apr 2021
#
# Title: PM lauds the completion of Arch closure of the Chenab Bridge, World's highest Railway Bridge
# Publish Date: Posted On: 05 Apr 2021
#
# Title: PM to interact with students, teachers and parents at "Pariksha Pe Charcha 2021" on 7th April, 2021
# Publish Date: Posted On: 05 Apr 2021
#
# Title: PM pays tributes to Babu Jagjivan Ram on his Jayanti
# Publish Date: Posted On: 05 Apr 2021
#
# Title: PM reviews COVID-19 Pandemic situation and Vaccination Program in India
# Publish Date: Posted On: 04 Apr 2021
#
# Title: PM condoles the passing away of Geeta Press President, Radheshyam Khemka
# Publish Date: Posted On: 04 Apr 2021
#
# Title: PM condoles demise of former Union Minister, Shri Digvijaysinh Zala
# Publish Date: Posted On: 04 Apr 2021
#
# Title: PM greets people on Easter
# Publish Date: Posted On: 04 Apr 2021
#
# Title: Good Friday reminds us about the struggles and sacrifices of Jesus Christ:PM
# Publish Date: Posted On: 02 Apr 2021
#
# Title: PM congratulates Rajinikanth for Dadasaheb Phalke Award
# Publish Date: Posted On: 01 Apr 2021
#
# Title: PM bows to His Holiness Dr. Sree Sree Sree Sivakumara Swamigalu on his Jayanti
# Publish Date: Posted On: 01 Apr 2021
#
# Title: PM greets people of Odisha on Utkala Dibasa
# Publish Date: Posted On: 01 Apr 2021
#
# Title: Cabinet approves Agreement between the Government of India and the Government of the United Kingdom of Great Britain and Northern Ireland on Customs Cooperation and Mutual Administrative Assistance in Customs Matters
# Publish Date: Posted On: 28 Apr 2021
#
# Title: MoU between the India and Bangladesh on the establishment of a framework of cooperation in the area of trade remedial measures
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Cabinet approves Memorandum of Understanding between the Institute of Chartered Accountants of India and Chartered Accountants Australia and New Zealand
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Cabinet approves Mutual Recognition Agreement between the Institute of Chartered Accounts of India and theCertified Practising Accountant,Australia
# Publish Date: Posted On: 20 Apr 2021
#
# Title: MoU between Competition Commission of India (CCI) and Administrative Council for Economic Defense of Brazil (CADE)
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Cabinet approves Bangalore Metro Rail Project Phase 2A and Phase 2B
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Cabinet approves Amendments to the Finance Bill, 2021
# Publish Date: Posted On: 20 Apr 2021
#
# Title: Union Cabinet approves Production Linked Incentive (PLI) Scheme for White Goods (Air Conditioners and LED Lights)
# Publish Date: Posted On: 07 Apr 2021
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 31
#      29 for article in news_articles:
#      30     title = article.find_element(By.CSS_SELECTOR, 'a.listLeftrel2').text
# ---> 31     publish_date = article.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
#      32     print(f"Title: {title}\nPublish Date: {publish_date}\n")
#      34 # Close the browser window
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'

time.sleep(20) 
# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()
time.sleep(4) 
# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
month_dropdown.select_by_value('4')  # Replace '4' with the desired month

# Re-locate the year dropdown after interacting with day and month dropdowns
year_dropdown = Select(driver.find_element(By.ID, "ContentPlaceHolder1_ddlYear"))
year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

# Wait for the page to update with the selected date's news
time.sleep(20)  # Adjust the sleep duration based on your website's loading time

# Scraping news articles
link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
for link_element in link_elements:
    link_text = link_element.text
    link_element.click()

    # Wait for the page to load
    time.sleep(2)  # Adjust the sleep duration based on your website's loading time

    # Scraping data
    content_div = driver.find_element(By.CLASS_NAME, 'innner-page-main-about-us-content-right-part')
    content_paragraphs = content_div.find_elements(By.TAG_NAME, 'p')
    for paragraph in content_paragraphs:
        paragraph_text = paragraph.text
        print(f"Link: {link_text}\nContent: {paragraph_text}\n")

    # Go back to the previous page to click the next link
    driver.back()
    
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[92], line 53
#      50 time.sleep(2)  # Adjust the sleep duration based on your website's loading time
#      52 # Scraping data
# ---> 53 content_div = driver.find_element(By.CLASS_NAME, 'innner-page-main-about-us-content-right-part')
#      54 content_paragraphs = content_div.find_elements(By.TAG_NAME, 'p')
#      55 for paragraph in content_paragraphs:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".innner-page-main-about-us-content-right-part"}
#   (Session info: chrome=121.0.6167.185); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF754E17012+3522402]
# 	(No symbol) [0x00007FF754A38352]
# 	(No symbol) [0x00007FF7548E5ABB]
# 	(No symbol) [0x00007FF75492BF0E]
# 	(No symbol) [0x00007FF75492C08C]
# 	(No symbol) [0x00007FF75496E437]
# 	(No symbol) [0x00007FF75494F09F]
# 	(No symbol) [0x00007FF75496BDA3]
# 	(No symbol) [0x00007FF75494EE03]
# 	(No symbol) [0x00007FF75491F4D4]
# 	(No symbol) [0x00007FF7549205F1]
# 	GetHandleVerifier [0x00007FF754E49B9D+3730157]
# 	GetHandleVerifier [0x00007FF754E9F02D+4079485]
# 	GetHandleVerifier [0x00007FF754E975D3+4048163]
# 	GetHandleVerifier [0x00007FF754B6A649+718233]
# 	(No symbol) [0x00007FF754A44A3F]
# 	(No symbol) [0x00007FF754A3FA94]
# 	(No symbol) [0x00007FF754A3FBC2]
# 	(No symbol) [0x00007FF754A2F2E4]
# 	BaseThreadInitThunk [0x00007FFF64A8257D+29]
# 	RtlUserThreadStart [0x00007FFF6562AA58+40]

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(30)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
month_dropdown.select_by_value('4')  # Replace '4' with the desired month

# Re-locate the year dropdown after interacting with day and month dropdowns
year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

# Wait for the page to update with the selected date's news
time.sleep(20)  # Adjust the sleep duration based on your website's loading time

# Scraping news articles
link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')

# Iterate through each link
for link_element in link_elements:
    link_text = link_element.text
    link_element.click()

    # Wait for the page to load, specifically for the div with class 'innner-page-main-about-us-content-right-part'
    try:
        content_div = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, 'bottomrel'))
        )
        print(content_div)
        

        # Find all <p> tags within the specified div
        content_paragraphs = content_div.find_elements(By.TAG_NAME, 'p')
        print(content_paragraphs)
        time.sleep(10)

        # Concatenate all text content into a single line until encountering "***"
        concatenated_text = ''
        for paragraph in content_paragraphs:
            paragraph_text = paragraph.text
            concatenated_text += paragraph_text + ' '

        # Print or use the concatenated text as needed
        print(f"Link: {link_text}\nContent: {concatenated_text}\n")

    except Exception as e:
        print(f"Error: {e}")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[3], line 49
#      46 time.sleep(20)  # Adjust the sleep duration based on your website's loading time
#      48 # Scraping news articles
# ---> 49 link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
#      51 # Iterate through each link
#      52 for link_element in link_elements:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B8ECAD22+56930]
# 	(No symbol) [0x00007FF6B8E3F622]
# 	(No symbol) [0x00007FF6B8CF42E5]
# 	(No symbol) [0x00007FF6B8CD1D4C]
# 	(No symbol) [0x00007FF6B8D623F7]
# 	(No symbol) [0x00007FF6B8D77891]
# 	(No symbol) [0x00007FF6B8D5BA43]
# 	(No symbol) [0x00007FF6B8D2D438]
# 	(No symbol) [0x00007FF6B8D2E4D1]
# 	GetHandleVerifier [0x00007FF6B9246AAD+3709933]
# 	GetHandleVerifier [0x00007FF6B929FFED+4075821]
# 	GetHandleVerifier [0x00007FF6B929817F+4043455]
# 	GetHandleVerifier [0x00007FF6B8F69756+706710]
# 	(No symbol) [0x00007FF6B8E4B8FF]
# 	(No symbol) [0x00007FF6B8E46AE4]
# 	(No symbol) [0x00007FF6B8E46C3C]
# 	(No symbol) [0x00007FF6B8E368F4]
# 	BaseThreadInitThunk [0x00007FFA56FD257D+29]
# 	RtlUserThreadStart [0x00007FFA5804AA58+40]

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(30)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day
ministry_arr=[61, 75, 80, 72, 14, 45, 56, 35, 1330, 27, 58, 41, 26, 42, 16, 24, 60, 39, 1440, 66, 17, 33, 57, 48, 73, 67, 8, 1323, 30, 4, 15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21, 7, 51, 44, 65, 28, 59, 10, 12, 6, 20, 79, 52, 23, 69, 43, 13, 46, 77, 50, 55, 18, 25, 19, 36, 49, 32, 38, 64, 9, 78]
ministry_dropdown=Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
ministry_dropdown.select_by_value('0')
month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
month_dropdown.select_by_value('4')  # Replace '4' with the desired month

# Re-locate the year dropdown after interacting with day and month dropdowns
year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

# Wait for the page to update with the selected date's news
time.sleep(20)  # Adjust the sleep duration based on your website's loading time

# Scraping news articles
link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')

# Iterate through each link
for link_element in link_elements:
    link_text = link_element.text
    onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]

    # Build the iframe URL
    iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
    # Open a new tab/window and switch to it
    driver.execute_script("window.open('', '_blank');")
    driver.switch_to.window(driver.window_handles[1])
    # Open the iframe URL in the new tab/window
    driver.get(iframe_url)
    time.sleep(10)
    # Find the input tag by ID
    input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
    # Extract the value attribute text
    value_text = input_tag.get_attribute('value')
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(value_text, 'html.parser')
    # Find all paragraphs in the HTML content
    paragraphs = soup.find_all('p')
    # Extract and print the text content of each paragraph
    concatenated_text = ''
    for paragraph in paragraphs:
        paragraph_text = paragraph.text
        concatenated_text += paragraph_text + ' '
    print(f"Link: {link_text}\nContent: {concatenated_text}\n")
    # Close the current tab/window and switch back to the main window
    driver.close()
    driver.switch_to.window(driver.window_handles[0])

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 9
#       6 from bs4 import BeautifulSoup
#       8 # Set up the Selenium webdriver
# ----> 9 driver = webdriver.Chrome()
#      11 # Replace 'your_website_url' with the actual URL of your website
#      12 website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:49, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      37 """Creates a new WebDriver instance of the ChromiumDriver. Starts the
#      38 service and then creates new WebDriver instance of ChromiumDriver.
#      39
#    (...)
#      45  - keep_alive - Whether to configure ChromiumRemoteConnection to use HTTP keep-alive.
#      46 """
#      47 self.service = service
# ---> 49 self.service.path = DriverFinder.get_path(self.service, options)
#      50 self.service.start()
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      36 path = service.path
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#      40     msg = f"Unable to obtain driver for {options.capabilities['browserName']} using Selenium Manager."
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:106, in SeleniumManager.driver_location(self, options)
#     103     value = proxy.ssl_proxy if proxy.ssl_proxy else proxy.http_proxy
#     104     args.append(value)
# --> 106 output = self.run(args)
#     108 browser_path = output["browser_path"]
#     109 driver_path = output["driver_path"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:137, in SeleniumManager.run(args)
#     135 try:
#     136     if sys.platform == "win32":
# --> 137         completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     138     else:
#     139         completed_proc = subprocess.run(args, capture_output=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1207, in Popen.communicate(self, input, timeout)
#    1204     endtime = None
#    1206 try:
# -> 1207     stdout, stderr = self._communicate(input, endtime, timeout)
#    1208 except KeyboardInterrupt:
#    1209     # https://bugs.python.org/issue25942
#    1210     # See the detailed comment in .wait().
#    1211     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1581, in Popen._communicate(self, input, endtime, orig_timeout)
#    1577 # Wait for the reader threads, or time out.  If we time out, the
#    1578 # threads remain reading and the fds left open in case the user
#    1579 # calls communicate again.
#    1580 if self.stdout is not None:
# -> 1581     self.stdout_thread.join(self._remaining_time(endtime))
#    1582     if self.stdout_thread.is_alive():
#    1583         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import re
import csv

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(30)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [61, 75, 80, 72, 14, 45, 56, 35, 1330, 27, 58, 41, 26, 42, 16, 24, 60, 39, 1440, 66, 17, 33, 57, 48, 73, 67, 8, 1323, 30, 4, 15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21, 7, 51, 44, 65, 28, 59, 10, 12, 6, 20, 79, 52, 23, 69, 43, 13, 46, 77, 50, 55, 18, 25, 19, 36, 49, 32, 38, 64, 9, 78]

# Create a CSV file and write the header
csv_file_path = 'output.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8-sig') as csv_file:
    csv_writer = csv.writer(csv_file)
    # csv_writer.writerow(['Month', 'Ministry', 'Title', 'Content'])

    # Iterate through each month
    for month_value in range(8, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2022')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(20)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(20)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                # link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
                 # Scraping news articles
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul')
            except:
                link_elements = []
            
            # Iterate through each link
            for link_element in link_elements:
                ele = link_element.find_element(By.CSS_SELECTOR, 'a.listLeftrel2')
                title=ele.text
                publish_date_text = link_element.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
                publish_date = publish_date_text.replace("प्रविष्टि तिथि:", "")
                
                onclick_value = ele.get_attribute('onclick').split('(')[-1].split(')')[0]

                
                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(10)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\\s\\s\*', x))
                
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')
                
                        while current_paragraph and not re.search(r'\\s\\s\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    # csv_writer.writerow([month_value, ministry_value, title, concatenated_text.strip()])
                    # Write the data to the CSV file
                    
                    print(f"Link: {title}\n  Date :{publish_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 11
#       8 import csv
#      10 # Set up the Selenium webdriver
# ---> 11 driver = webdriver.Chrome()
#      13 # Replace 'your_website_url' with the actual URL of your website
#      14 website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:61, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#      60 try:
# ---> 61     super().__init__(command_executor=executor, options=options)
#      62 except Exception:
#      63     self.quit()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     342     elif "sessionId" not in params:
#     343         params["sessionId"] = self.session_id
# --> 345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
#     347     self.error_handler.check_response(response)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     300 trimmed = self._trim_large_entries(params)
#     301 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302 return self._request(command_info[0], url, body=data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     319     body = None
#     321 if self.keep_alive:
# --> 322     response = self._conn.request(method, url, body=body, headers=headers)
#     323     statuscode = response.status
#     324 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import re
import csv

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(25)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [61, 75, 80, 72, 14, 45, 56, 35, 1330, 27]

# Create a CSV file and write the header
csv_file_path = 'output.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8-sig') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Title', 'Date', 'Content'])

    # Iterate through each month
    for month_value in range(1, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(10)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(10)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul')
            except:
                link_elements = []
            
            # Iterate through each link
            for link_element in link_elements:
                ele = link_element.find_element(By.CSS_SELECTOR, 'a.listLeftrel2')
                title=ele.text
                publish_date_text = link_element.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
                publish_date = publish_date_text.replace("प्रविष्टि तिथि:", "")
                
                onclick_value = ele.get_attribute('onclick').split('(')[-1].split(')')[0]

                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(20)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', string=lambda x: x and re.search(r'\\s\\s\*', x))

                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')
                
                        while current_paragraph and not re.search(r'\\s\\s\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')
                            time.sleep(10)
                    csv_writer.writerow([month_value, ministry_value, title, concatenated_text.strip()])
                    # Write the data to the CSV file
                    
                    print(f"Link: {title}\n  Date :{publish_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[45], line 93
#      91 time.sleep(20)
#      92 # Find the input tag by ID
# ---> 93 input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
#      94 # Extract the value attribute text
#      95 value_text = input_tag.get_attribute('value')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B8ECAD22+56930]
# 	(No symbol) [0x00007FF6B8E3F622]
# 	(No symbol) [0x00007FF6B8CF42E5]
# 	(No symbol) [0x00007FF6B8CD1D4C]
# 	(No symbol) [0x00007FF6B8D623F7]
# 	(No symbol) [0x00007FF6B8D77891]
# 	(No symbol) [0x00007FF6B8D5BA43]
# 	(No symbol) [0x00007FF6B8D2D438]
# 	(No symbol) [0x00007FF6B8D2E4D1]
# 	GetHandleVerifier [0x00007FF6B9246AAD+3709933]
# 	GetHandleVerifier [0x00007FF6B929FFED+4075821]
# 	GetHandleVerifier [0x00007FF6B929817F+4043455]
# 	GetHandleVerifier [0x00007FF6B8F69756+706710]
# 	(No symbol) [0x00007FF6B8E4B8FF]
# 	(No symbol) [0x00007FF6B8E46AE4]
# 	(No symbol) [0x00007FF6B8E46C3C]
# 	(No symbol) [0x00007FF6B8E368F4]
# 	BaseThreadInitThunk [0x00007FFA56FD257D+29]
# 	RtlUserThreadStart [0x00007FFA5804AA58+40]

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import re
import csv

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(30)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [61, 75, 80, 72, 14, 45, 56, 35, 1330, 27, 58, 41, 26, 42, 16, 24, 60, 39, 1440, 66, 17, 33, 57, 48, 73, 67, 8, 1323, 30, 4, 15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21, 7, 51, 44, 65, 28, 59, 10, 12, 6, 20, 79, 52, 23, 69, 43, 13, 46, 77, 50, 55, 18, 25, 19, 36, 49, 32, 38, 64, 9, 78]

# Create a CSV file and write the header
csv_file_path = 'output.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8-sig') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Month', 'Ministry', 'Title', 'Content'])

    # Iterate through each month
    for month_value in range(1, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2022')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(20)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(20)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul')
            except:
                link_elements = []
            
            # Iterate through each link
            for link_element in link_elements:
                ele = link_element.find_element(By.CSS_SELECTOR, 'a.listLeftrel2')
                title=ele.text
                publish_date_text = link_element.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
                publish_date = publish_date_text.replace("प्रविष्टि तिथि:", "")
                
                onclick_value = ele.get_attribute('onclick').split('(')[-1].split(')')[0]

                
                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(10)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\\s\\s\*', x))
                
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')
                
                        while current_paragraph and not re.search(r'\\s\\s\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    # csv_writer.writerow([month_value, ministry_value, title, concatenated_text.strip()])
                    # Write the data to the CSV file
                    
                    print(f"Link: {title}\n  Date :{publish_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# C:\Users\Chaitanya\AppData\Local\Temp\ipykernel_14172\4060378714.py:103: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\\s\\s\*', x))
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[48], line 64
#      62 # Iterate through each ministry
#      63 for ministry_value in ministry_arr:
# ---> 64     ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
#      65     ministry_dropdown.select_by_value(str(ministry_value))
#      67     # Wait for the page to update with the selected ministry's news
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B8ECAD22+56930]
# 	(No symbol) [0x00007FF6B8E3F622]
# 	(No symbol) [0x00007FF6B8CF42E5]
# 	(No symbol) [0x00007FF6B8CD1D4C]
# 	(No symbol) [0x00007FF6B8D623F7]
# 	(No symbol) [0x00007FF6B8D77891]
# 	(No symbol) [0x00007FF6B8D5BA43]
# 	(No symbol) [0x00007FF6B8D2D438]
# 	(No symbol) [0x00007FF6B8D2E4D1]
# 	GetHandleVerifier [0x00007FF6B9246AAD+3709933]
# 	GetHandleVerifier [0x00007FF6B929FFED+4075821]
# 	GetHandleVerifier [0x00007FF6B929817F+4043455]
# 	GetHandleVerifier [0x00007FF6B8F69756+706710]
# 	(No symbol) [0x00007FF6B8E4B8FF]
# 	(No symbol) [0x00007FF6B8E46AE4]
# 	(No symbol) [0x00007FF6B8E46C3C]
# 	(No symbol) [0x00007FF6B8E368F4]
# 	BaseThreadInitThunk [0x00007FFA56FD257D+29]
# 	RtlUserThreadStart [0x00007FFA5804AA58+40]

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import re
import csv

# Set up the Selenium webdriver
driver = webdriver.Chrome()

# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/PressReleseDetail.aspx?PRID=2010736'
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(15)

# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()

# Navigate to 'प्रेस विज्ञप्ति'
time.sleep(20)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [61, 75, 80, 72, 14, 45, 56, 35, 1330, 27, 58, 41, 26, 42, 16, 24, 60, 39, 1440, 66, 17, 33, 57, 48, 73, 67, 8, 1323, 30, 4, 15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21, 7, 51, 44, 65, 28, 59, 10, 12, 6, 20, 79, 52, 23, 69, 43, 13, 46, 77, 50, 55, 18, 25, 19, 36, 49, 32, 38, 64, 9, 78]

# Create a CSV file and write the header
csv_file_path = 'output.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8-sig') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Title', 'Content'])

    # Iterate through each month
    for month_value in range(1, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2020')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(10)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(10)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
                 # Scraping news articles
                #link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul')
            except:
                link_elements = []
            print(link_elements)
            # Iterate through each link
            for link_element in link_elements:
                # ele = link_element.find_element(By.CSS_SELECTOR, 'a.listLeftrel2')
                title=link_element.text
                # publish_date_text = link_element.find_element(By.CSS_SELECTOR, 'span.publishdatesmall').text
                # publish_date = publish_date_text.replace("प्रविष्टि तिथि:", "")
                
                onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]

                
                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                time.sleep(20)
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(10)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = inner_soup.find_all('p', text=True)

                # Define the regular expression pattern to match
                pattern = re.compile(r'\*\*')

                # Check if there are any target paragraphs
                if target_paragraphs:
                    concatenated_text = ""
                    for paragraph in target_paragraphs:
                    # Break the loop when the condition (regular expression) is met
                        if pattern.search(paragraph.text):
                            break
                        concatenated_text += paragraph.text.strip() + " "

      
                    csv_writer.writerow([month_value, ministry_value, title, concatenated_text.strip()])
                    # Write the data to the CSV file
                    
                    print(f"Link: {title}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.283")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.284")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.285")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.286")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.287")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.288")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.289")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.290")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.291")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.292")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.293")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.294")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.295")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.296")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.297")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.298")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.299")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.300")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.301")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.302")>, <selenium.webdriver.remote.webelement.WebElement (session="4cd3c1bec3de109c65378f3ba440fcda", element="f.6D111A6661BE4D9B6024DC2BAF26E18E.d.BD1695F1FEC2BE04DF6382A9435A13EA.e.303")>]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 93
#      91 driver.execute_script("window.open('', '_blank');")
#      92 time.sleep(20)
# ---> 93 driver.switch_to.window(driver.window_handles[1])
#      94 # Open the iframe URL in the new tab/window
#      95 driver.get(iframe_url)
#
# IndexError: list index out of range

# %%
from bs4 import BeautifulSoup
import re

# The provided HTML content
html_content = """
<input type="hidden" name="ltrDescriptionn" id="ltrDescriptionn" value="<p style=&quot;text-align:justify&quot;><span style=&quot;font-size:16px&quot;>राष्ट्रपति श्री राम नाथ कोविंद ने पुथांडु पिरापु,रंगाली बिहू,नब वर्ष और वैसाखड़ी,जो 14 और 15 अप्रैल, 2021 को देश के विभिन्न भागों में मनाए जाएंगे, की पूर्व</span>&amp;nbsp;<span style=&quot;font-size:16px&quot;>संध्या पर अपने संदेश में कहा-</span></p>

<p style=&quot;text-align:justify&quot;><span style=&quot;font-size:16px&quot;>&amp;ldquo;पुथांडु पिरापु,रंगाली बिहू,नब वर्ष और वैसाखड़ी के शुभ अवसर पर, मैं भारत और विदेश में रह रहे सभी भारतीयों को हार्दिक बधाई और शुभकामनाएं देता हूं।</span></p>

<p style=&quot;text-align:justify&quot;><span style=&quot;font-size:16px&quot;>ये नव वर्ष उत्सव हमारे देश के विभिन्न भागों में नई उम्मीदों और उत्साह के साथ अलग-अलग तरीके से मनाए जाते हैं। साथ ही यह हमारी विविधता और बहु सांस्कृतिक परम्परा के प्रतीक हैं। ये उत्सव हमारे किसानों के अथक परिश्रम के प्रति सम्मान को प्रकट करते हैं।</span></p>

<p style=&quot;text-align:justify&quot;><span style=&quot;font-size:16px&quot;>इस अवसर पर, आइए हम अपने देशवासियों की शांति, संपन्नता और उल्लास व राष्ट्र की एकता और भाईचारे को बढ़ाने का संदेश फैलाने का संकल्प लेते हैं।</span></p>

<p style=&quot;text-align:justify&quot;><span style=&quot;font-size:16px&quot;>हम सभी स्वस्थ और उद्यमी बने रहें तथा देश की प्रगति के लिए एक नए उत्साह के साथ एकजुट होकर आगे बढ़ें।&amp;rdquo;</span></p>

<p style=&quot;text-align:justify&quot;><a href=&quot;https://static.pib.gov.in/WriteReadData/specificdocs/documents/2021/apr/doc202141321.pdf&quot; style=&quot;font-size: 16px;&quot; target=&quot;_blank&quot;>कृपया राष्ट्रपति का संदेश देखने के लिए यहां क्लिक करें।</a></p>

<p style=&quot;text-align:center&quot;><span style=&quot;font-size:16px&quot;>**</span></p>

<p style=&quot;text-align:justify&quot;>&amp;nbsp;</p>

<p style=&quot;text-align:justify&quot;><strong><span style=&quot;font-size:16px&quot;>एमजी/एएम/एमपी</span></strong></p>
">
"""
# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the input tag by ID
input_tag = soup.find('input', {'id': 'ltrDescriptionn'})

# Extract the value attribute text
value_text = input_tag.get('value')

# Parse the HTML content inside the value attribute
inner_soup = BeautifulSoup(value_text, 'html.parser')
target_paragraphs = inner_soup.find_all('p', text=True)

# Define the regular expression pattern to match
pattern = re.compile(r'\*\*')

# Check if there are any target paragraphs
if target_paragraphs:
    # Concatenate the text content of all paragraphs until the condition is met
    concatenated_text = ""
    for paragraph in target_paragraphs:
        # Break the loop when the condition (regular expression) is met
        if pattern.search(paragraph.text):
            break
        concatenated_text += paragraph.text.strip() + " "

    # Print the concatenated text
    print(f"Content: {concatenated_text.strip()}")
# Out:
# Content: “पुथांडु पिरापु,रंगाली बिहू,नब वर्ष और वैसाखड़ी के शुभ अवसर पर, मैं भारत और विदेश में रह रहे सभी भारतीयों को हार्दिक बधाई और शुभकामनाएं देता हूं। ये नव वर्ष उत्सव हमारे देश के विभिन्न भागों में नई उम्मीदों और उत्साह के साथ अलग-अलग तरीके से मनाए जाते हैं। साथ ही यह हमारी विविधता और बहु सांस्कृतिक परम्परा के प्रतीक हैं। ये उत्सव हमारे किसानों के अथक परिश्रम के प्रति सम्मान को प्रकट करते हैं। इस अवसर पर, आइए हम अपने देशवासियों की शांति, संपन्नता और उल्लास व राष्ट्र की एकता और भाईचारे को बढ़ाने का संदेश फैलाने का संकल्प लेते हैं। हम सभी स्वस्थ और उद्यमी बने रहें तथा देश की प्रगति के लिए एक नए उत्साह के साथ एकजुट होकर आगे बढ़ें।” कृपया राष्ट्रपति का संदेश देखने के लिए यहां क्लिक करें।
# C:\Users\Chaitanya\AppData\Local\Temp\ipykernel_14172\1425749739.py:36: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   target_paragraphs = inner_soup.find_all('p', text=True)

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import re
import csv
from dateutil import parser

# Set up the ChromeOptions
# Set up the Selenium webdriver
driver = webdriver.Chrome()


# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/indexd.aspx'
driver.get(website_url)

# Select Hindi language

reg_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlregion'))
reg_dropdown.select_by_value('1')
time.sleep(15)
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('9')
time.sleep(25)
# Navigate to 'Press Releases'
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=9&RegionId=1"]')
press_releases_link.click()


time.sleep(4)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(4)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [61, 75, 80, 72, 14, 45, 56, 35, 1330, 27]
# Create a CSV file and write the header
csv_file_path = 'output_mar.csv'
with open(csv_file_path, 'a', newline='', encoding='utf-8-sig') as csv_file: 
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Title','Date', 'Content'])
    # Iterate through each month
    for month_value in range(6, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2021')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(6)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(4)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
            except:
                link_elements = []

            # Iterate through each link
            for link_element in link_elements:
                title = link_element.text
                onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]


                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(7)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
                date_element = driver.find_element(By.CSS_SELECTOR, 'div.ReleaseDateSubHeaddateTime')
                # Extract the text content from the element
                publish_date_text = date_element.text
                
                # Use dateutil.parser to parse the date
                try:
                    parsed_date = parser.parse(publish_date_text, fuzzy=True)
                    formatted_date = parsed_date.strftime('%d-%m-%Y')
                except ValueError:
                    print("N/A")
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')

                        while current_paragraph and not re.search(r'\*\s*\*\s*\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    csv_writer.writerow([title,formatted_date, concatenated_text.strip()])
                    
                    #print(f"Link: {title}\n  Date :{formatted_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# There was an error managing chromedriver (error sending request for url (https://googlechromelabs.github.io/chrome-for-testing/known-good-versions-with-downloads.json): error trying to connect: dns error: No such host is known. (os error 11001)); using driver found in the cache
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event): error trying to connect: dns error: No such host is known. (os error 11001)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[83], line 18
#      16 # Replace 'your_website_url' with the actual URL of your website
#      17 website_url = 'https://www.pib.gov.in/indexd.aspx'
# ---> 18 driver.get(website_url)
#      20 # Select Hindi language
#      22 reg_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlregion'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B8ECAD22+56930]
# 	(No symbol) [0x00007FF6B8E3F622]
# 	(No symbol) [0x00007FF6B8CF42E5]
# 	(No symbol) [0x00007FF6B8CF011A]
# 	(No symbol) [0x00007FF6B8CE29F4]
# 	(No symbol) [0x00007FF6B8CE3D29]
# 	(No symbol) [0x00007FF6B8CE2CF3]
# 	(No symbol) [0x00007FF6B8CE1EF4]
# 	(No symbol) [0x00007FF6B8CE1E11]
# 	(No symbol) [0x00007FF6B8CE0625]
# 	(No symbol) [0x00007FF6B8CE0EDC]
# 	(No symbol) [0x00007FF6B8CF69FD]
# 	(No symbol) [0x00007FF6B8D78B47]
# 	(No symbol) [0x00007FF6B8D5BC9A]
# 	(No symbol) [0x00007FF6B8D781E2]
# 	(No symbol) [0x00007FF6B8D5BA43]
# 	(No symbol) [0x00007FF6B8D2D438]
# 	(No symbol) [0x00007FF6B8D2E4D1]
# 	GetHandleVerifier [0x00007FF6B9246AAD+3709933]
# 	GetHandleVerifier [0x00007FF6B929FFED+4075821]
# 	GetHandleVerifier [0x00007FF6B929817F+4043455]
# 	GetHandleVerifier [0x00007FF6B8F69756+706710]
# 	(No symbol) [0x00007FF6B8E4B8FF]
# 	(No symbol) [0x00007FF6B8E46AE4]
# 	(No symbol) [0x00007FF6B8E46C3C]
# 	(No symbol) [0x00007FF6B8E368F4]
# 	BaseThreadInitThunk [0x00007FFA56FD257D+29]
# 	RtlUserThreadStart [0x00007FFA5804AA58+40]

# %%
#For English
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import re
import csv
from dateutil import parser

# Set up the ChromeOptions
# Set up the Selenium webdriver
driver = webdriver.Chrome()


# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/indexd.aspx'
# Replace 'your_website_url' with the actual URL of your website
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(20)
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()


time.sleep(4)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(8)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [58, 41, 26, 42, 16, 24, 60, 39, 1440, 66]
# Create a CSV file and write the header
csv_file_path = 'news/hindii_2023.csv'
with open(csv_file_path, 'a', newline='', encoding='utf-8-sig') as csv_file: 
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Link','Title','Language','Date', 'Content','Classifier'])
    # Iterate through each month
    for month_value in range(1, 5):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2023')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(4)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(4)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
            except:
                link_elements = []

            # Iterate through each link
            for link_element in link_elements:
                title = link_element.text
                onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]


                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(8)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
                date_element = driver.find_element(By.CSS_SELECTOR, 'div.ReleaseDateSubHeaddateTime')
                # Extract the text content from the element
                publish_date_text = date_element.text
                
                # Use dateutil.parser to parse the date
                try:
                    parsed_date = parser.parse(publish_date_text, fuzzy=True)
                    formatted_date = parsed_date.strftime('%d-%m-%Y')
                except ValueError:
                    print("N/A")
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')

                        while current_paragraph and not re.search(r'\*\s*\*\s*\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    csv_writer.writerow([iframe_url,title,"Hindi",formatted_date, concatenated_text.strip(),"Government"])
                    
                    #print(f"Link: {title}\n  Date :{formatted_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# C:\Users\Chaitanya\AppData\Local\Temp\ipykernel_17224\1456973180.py:98: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
# C:\Users\Chaitanya\AppData\Local\Programs\Python\Python311\Lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname PIB identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[2], line 79
#      77 # Iterate through each link
#      78 for link_element in link_elements:
# ---> 79     title = link_element.text
#      80     onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]
#      83     # Build the iframe URL
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=123.0.6312.59); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF65DDA70C2+63090]
# 	(No symbol) [0x00007FF65DD12D12]
# 	(No symbol) [0x00007FF65DBAEC65]
# 	(No symbol) [0x00007FF65DBB3D21]
# 	(No symbol) [0x00007FF65DBB6159]
# 	(No symbol) [0x00007FF65DBB6200]
# 	(No symbol) [0x00007FF65DBEFE1B]
# 	(No symbol) [0x00007FF65DC16FDA]
# 	(No symbol) [0x00007FF65DBEA00A]
# 	(No symbol) [0x00007FF65DC171F0]
# 	(No symbol) [0x00007FF65DC33412]
# 	(No symbol) [0x00007FF65DC16D83]
# 	(No symbol) [0x00007FF65DBE83A8]
# 	(No symbol) [0x00007FF65DBE9441]
# 	GetHandleVerifier [0x00007FF65E1A262D+4238301]
# 	GetHandleVerifier [0x00007FF65E1DF78D+4488509]
# 	GetHandleVerifier [0x00007FF65E1D7A6F+4456479]
# 	GetHandleVerifier [0x00007FF65DE80606+953270]
# 	(No symbol) [0x00007FF65DD1E5DF]
# 	(No symbol) [0x00007FF65DD192B4]
# 	(No symbol) [0x00007FF65DD193EB]
# 	(No symbol) [0x00007FF65DD09C24]
# 	BaseThreadInitThunk [0x00007FFF3C19257D+29]
# 	RtlUserThreadStart [0x00007FFF3D64AA48+40]

# %%
#For English
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import re
import csv
from dateutil import parser

# Set up the ChromeOptions
# Set up the Selenium webdriver
driver = webdriver.Chrome()


# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/indexd.aspx'
# Replace 'your_website_url' with the actual URL of your website
driver.get(website_url)

# Select Hindi language
language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(30)
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()


time.sleep(4)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(8)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21]

# Create a CSV file and write the header
csv_file_path = 'news/hindii_2023.csv'
with open(csv_file_path, 'a', newline='', encoding='utf-8-sig') as csv_file: 
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Link','Title','Language','Date', 'Content','Classifier'])
    # Iterate through each month
    for month_value in range(1, 13):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))
        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2023')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(4)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(4)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
            except:
                link_elements = []

            # Iterate through each link
            for link_element in link_elements:
                title = link_element.text
                onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]


                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(8)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
                date_element = driver.find_element(By.CSS_SELECTOR, 'div.ReleaseDateSubHeaddateTime')
                # Extract the text content from the element
                publish_date_text = date_element.text
                
                # Use dateutil.parser to parse the date
                try:
                    parsed_date = parser.parse(publish_date_text, fuzzy=True)
                    formatted_date = parsed_date.strftime('%d-%m-%Y')
                except ValueError:
                    print("N/A")
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')

                        while current_paragraph and not re.search(r'\*\s*\*\s*\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    csv_writer.writerow([iframe_url,title,"Hindi",formatted_date, concatenated_text.strip(),"Government"])
                    
                    #print(f"Link: {title}\n  Date :{formatted_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[7], line 14
#      10 from dateutil import parser
#      12 # Set up the ChromeOptions
#      13 # Set up the Selenium webdriver
# ---> 14 driver = webdriver.Chrome()
#      17 # Replace 'your_website_url' with the actual URL of your website
#      18 website_url = 'https://www.pib.gov.in/indexd.aspx'
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:61, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#      60 try:
# ---> 61     super().__init__(command_executor=executor, options=options)
#      62 except Exception:
#      63     self.quit()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: received Inspector.detached event
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=123.0.6312.59)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF65DDA70C2+63090]
# 	(No symbol) [0x00007FF65DD12D12]
# 	(No symbol) [0x00007FF65DBAEC65]
# 	(No symbol) [0x00007FF65DB9E172]
# 	(No symbol) [0x00007FF65DB9D825]
# 	(No symbol) [0x00007FF65DB9D104]
# 	(No symbol) [0x00007FF65DB9D021]
# 	(No symbol) [0x00007FF65DB9B0A8]
# 	(No symbol) [0x00007FF65DB9B8BC]
# 	(No symbol) [0x00007FF65DB9A306]
# 	(No symbol) [0x00007FF65DBA12D2]
# 	(No symbol) [0x00007FF65DB9A075]
# 	(No symbol) [0x00007FF65DB9CC2A]
# 	(No symbol) [0x00007FF65DB9B0A8]
# 	(No symbol) [0x00007FF65DB9B8BC]
# 	(No symbol) [0x00007FF65DB9A306]
# 	(No symbol) [0x00007FF65DB920F2]
# 	(No symbol) [0x00007FF65DB9A075]
# 	(No symbol) [0x00007FF65DB9995D]
# 	(No symbol) [0x00007FF65DB994DD]
# 	(No symbol) [0x00007FF65DBB0E31]
# 	(No symbol) [0x00007FF65DB8C140]
# 	(No symbol) [0x00007FF65DB8BBF0]
# 	(No symbol) [0x00007FF65DC20D5E]
# 	(No symbol) [0x00007FF65DC20830]
# 	(No symbol) [0x00007FF65DC16D83]
# 	(No symbol) [0x00007FF65DBE83A8]
# 	(No symbol) [0x00007FF65DBE9441]
# 	GetHandleVerifier [0x00007FF65E1A262D+4238301]
# 	GetHandleVerifier [0x00007FF65E1DF78D+4488509]
# 	GetHandleVerifier [0x00007FF65E1D7A6F+4456479]
# 	GetHandleVerifier [0x00007FF65DE80606+953270]
# 	(No symbol) [0x00007FF65DD1E5DF]
# 	(No symbol) [0x00007FF65DD192B4]
# 	(No symbol) [0x00007FF65DD193EB]
# 	(No symbol) [0x00007FF65DD09C24]
# 	BaseThreadInitThunk [0x00007FFF3C19257D+29]
# 	RtlUserThreadStart [0x00007FFF3D64AA48+40]

# %%
#For English
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import re
import csv
from dateutil import parser

# Set up the ChromeOptions
# Set up the Selenium webdriver
driver = webdriver.Chrome()


# Replace 'your_website_url' with the actual URL of your website
website_url = 'https://www.pib.gov.in/indexd.aspx'
# Replace 'your_website_url' with the actual URL of your website
driver.get(website_url)

language_dropdown = Select(driver.find_element(By.ID, 'Bar1_ddlLang'))
language_dropdown.select_by_value('2')

time.sleep(30)
press_releases_link = driver.find_element(By.CSS_SELECTOR, 'ul li a[href="/PMContents/PMContents.aspx?menuid=1&Lang=2&RegionId=3"]')
press_releases_link.click()


time.sleep(4)

# Click on the first article link
first_article_link = driver.find_element(By.CSS_SELECTOR, 'ul.num li a')
first_article_link.click()

time.sleep(8)

# Select the desired date
# Select the desired date (replace with your own logic if needed)
day_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlday'))
day_dropdown.select_by_value('0')  # Replace '1' with the desired day

# List of ministry values
ministry_arr = [15, 1340, 40, 31, 53, 5, 47, 11, 1336, 21,79, 52, 23, 69, 43, 13, 46, 77, 50, 55]
# Create a CSV file and write the header
csv_file_path = 'news/hindii_2023.csv'
with open(csv_file_path, 'a', newline='', encoding='utf-8-sig') as csv_file: 
    csv_writer = csv.writer(csv_file)
    #csv_writer.writerow(['Link','Title','Language','Date', 'Content','Classifier'])
    # Iterate through each month
    for month_value in range(3, 6):
        month_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMonth'))
        month_dropdown.select_by_value(str(month_value))

        # Re-locate the year dropdown after interacting with day and month dropdowns
        year_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlYear'))
        year_dropdown.select_by_value('2023')  # Replace '2021' with the desired year

        # Wait for the page to update with the selected month's news
        time.sleep(4)  # Adjust the sleep duration based on your website's loading time

        # Iterate through each ministry
        for ministry_value in ministry_arr:
            ministry_dropdown = Select(driver.find_element(By.ID, 'ContentPlaceHolder1_ddlMinistry'))
            ministry_dropdown.select_by_value(str(ministry_value))

            # Wait for the page to update with the selected ministry's news
            time.sleep(4)  # Adjust the sleep duration based on your website's loading time

            # Scraping news articles
            try:
                link_elements = driver.find_elements(By.CSS_SELECTOR, 'ul.leftul li a.listLeftrel2')
            except:
                link_elements = []
            # Iterate through each link
            for link_element in link_elements:
                title = link_element.text
                onclick_value = link_element.get_attribute('onclick').split('(')[-1].split(')')[0]


                # Build the iframe URL
                iframe_url = f'https://www.pib.gov.in/PressReleasePage.aspx?PRID={onclick_value}'
                # Open a new tab/window and switch to it
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                # Open the iframe URL in the new tab/window
                driver.get(iframe_url)
                time.sleep(8)
                # Find the input tag by ID
                input_tag = driver.find_element(By.ID, 'ltrDescriptionn')
                # Extract the value attribute text
                value_text = input_tag.get_attribute('value')
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(value_text, 'html.parser')
                # Find all paragraphs in the HTML content
                target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
                date_element = driver.find_element(By.CSS_SELECTOR, 'div.ReleaseDateSubHeaddateTime')
                # Extract the text content from the element
                publish_date_text = date_element.text
                
                # Use dateutil.parser to parse the date
                try:
                    parsed_date = parser.parse(publish_date_text, fuzzy=True)
                    formatted_date = parsed_date.strftime('%d-%m-%Y')
                except ValueError:
                    print("N/A")
                # Check if there are any target paragraphs
                if target_paragraphs:
                    # Find all previous siblings (preceding <p> tags) and concatenate their text content until the target paragraph
                    concatenated_text = ""
                    for target_paragraph in target_paragraphs:
                        current_paragraph = target_paragraph.find_previous('p')

                        while current_paragraph and not re.search(r'\*\s*\*\s*\*', current_paragraph.text):
                            concatenated_text = current_paragraph.text.strip() + " " + concatenated_text
                            current_paragraph = current_paragraph.find_previous('p')

                    csv_writer.writerow([iframe_url,title,"Hindi",formatted_date, concatenated_text.strip(),"Government"])
                    
                    #print(f"Link: {title}\n  Date :{formatted_date}\nContent:{concatenated_text.strip()}\n")
                
                # Close the current tab/window and switch back to the main window
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()
# Out:
# C:\Users\Chaitanya\AppData\Local\Temp\ipykernel_17224\848095023.py:96: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   target_paragraphs = soup.find_all('p', text=lambda x: x and re.search(r'\*\s*\*\s*\*', x))
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[15], line 87
#      85 driver.switch_to.window(driver.window_handles[1])
#      86 # Open the iframe URL in the new tab/window
# ---> 87 driver.get(iframe_url)
#      88 time.sleep(8)
#      89 # Find the input tag by ID
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=123.0.6312.59)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF65DDA70C2+63090]
# 	(No symbol) [0x00007FF65DD12D12]
# 	(No symbol) [0x00007FF65DBAEC65]
# 	(No symbol) [0x00007FF65DBAAC1A]
# 	(No symbol) [0x00007FF65DB9D514]
# 	(No symbol) [0x00007FF65DB9E8F8]
# 	(No symbol) [0x00007FF65DB9D7FF]
# 	(No symbol) [0x00007FF65DB9D104]
# 	(No symbol) [0x00007FF65DB9D021]
# 	(No symbol) [0x00007FF65DB9B0A8]
# 	(No symbol) [0x00007FF65DB9B8BC]
# 	(No symbol) [0x00007FF65DBB14AD]
# 	(No symbol) [0x00007FF65DC33D67]
# 	(No symbol) [0x00007FF65DC16FDA]
# 	(No symbol) [0x00007FF65DC33412]
# 	(No symbol) [0x00007FF65DC16D83]
# 	(No symbol) [0x00007FF65DBE83A8]
# 	(No symbol) [0x00007FF65DBE9441]
# 	GetHandleVerifier [0x00007FF65E1A262D+4238301]
# 	GetHandleVerifier [0x00007FF65E1DF78D+4488509]
# 	GetHandleVerifier [0x00007FF65E1D7A6F+4456479]
# 	GetHandleVerifier [0x00007FF65DE80606+953270]
# 	(No symbol) [0x00007FF65DD1E5DF]
# 	(No symbol) [0x00007FF65DD192B4]
# 	(No symbol) [0x00007FF65DD193EB]
# 	(No symbol) [0x00007FF65DD09C24]
# 	BaseThreadInitThunk [0x00007FFF3C19257D+29]
# 	RtlUserThreadStart [0x00007FFF3D64AA48+40]
